# %%
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import ipywidgets as widgets
from ipywidgets import Button, FloatSlider, HBox, VBox, Label
from IPython.display import display
from vtkmodules.util import numpy_support
import vtk

DATA_FILE = "mixture.vti"

def load_vti_data(file_path):
    reader = vtk.vtkXMLImageDataReader()
    reader.SetFileName(file_path)
    reader.Update()
    image_data = reader.GetOutput()
    array_data = image_data.GetPointData().GetArray(0)
    volume = numpy_support.vtk_to_numpy(array_data)
    dims = image_data.GetDimensions()
    volume = volume.reshape(dims, order="F")
    return volume, dims

volume_data, dims = load_vti_data(DATA_FILE)

values = volume_data.flatten()
min_iso = values.min()
max_iso = values.max()

x = np.arange(dims[0])
y = np.arange(dims[1])
z = np.arange(dims[2])
x, y, z = np.meshgrid(x, y, z, indexing="ij")

def plasma_single_color(isovalue):
    t = np.clip((isovalue-min_iso)/(max_iso-min_iso),0,1)
    c = px.colors.sample_colorscale("Plasma",[t])[0]
    return [[0,c],[1,c]]

isosurface = go.FigureWidget(
    data=[go.Isosurface(
        x=x.flatten(), y=y.flatten(), z=z.flatten(),
        value=values,
        isomin=0.0,
        isomax=0.0,
        surface_count=1,
        colorscale=plasma_single_color(0.0),
        caps=dict(x_show=False,y_show=False,z_show=False)
    )]
)
isosurface.update_layout(
    title="Isosurface",
    width=550,height=550,
    scene=dict(xaxis_title="X",yaxis_title="Y",zaxis_title="Z")
)

histogram = go.FigureWidget(
    data=[go.Histogram(x=values,nbinsx=50)]
)
histogram.update_layout(
    title="Histogram",
    width=550,height=550,
    xaxis_title="Scalar Values",
    yaxis_title="Frequency"
)

slider = FloatSlider(
    value=0.0,
    min=min_iso,
    max=max_iso,
    step=0.01,
    description="Isovalue",
    continuous_update=True
)

value_label = Label("0.00")

def update_plot(isovalue):
    value_label.value = f"{isovalue:.2f}"

    with isosurface.batch_update():
        isosurface.data[0].isomin = isovalue
        isosurface.data[0].isomax = isovalue
        isosurface.data[0].colorscale = plasma_single_color(isovalue)

    subset = values[(values>=isovalue-0.25) & (values<=isovalue+0.25)]

    with histogram.batch_update():
        histogram.data[0].x = subset
        histogram.update_xaxes(range=[isovalue-0.25,isovalue+0.25])

slider.observe(lambda c:update_plot(c["new"]),names="value")

reset = Button(description="Reset")

def reset_clicked(b):
    slider.value = 0.0
    value_label.value = "0.00"

    with isosurface.batch_update():
        isosurface.data[0].isomin = 0.0
        isosurface.data[0].isomax = 0.0
        isosurface.data[0].colorscale = plasma_single_color(0.0)

    with histogram.batch_update():
        histogram.data[0].x = values
        histogram.update_xaxes(range=[min_iso,max_iso])

reset.on_click(reset_clicked)

display(
    VBox([
        HBox([slider,value_label,reset]),
        HBox([isosurface,histogram])
    ])
)
